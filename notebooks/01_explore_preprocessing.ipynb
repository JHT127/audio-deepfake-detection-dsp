# %%
import sys
sys.path.append("..")
from src.preprocessing import load_audio, load_and_frame, get_spectrogram
import os

# %%
real_file = os.path.join("../data/raw/real", os.listdir("../data/raw/real")[0])
fake_file = os.path.join("../data/raw/fake", os.listdir("../data/raw/fake")[0])
print(real_file, fake_file)
# Out:
# ../data/raw/real\LA_E_1027220.flac ../data/raw/fake\LA_E_1025210.flac

# %%
frames = load_and_frame(real_file)
print("Frames shape:", frames.shape)

spec = get_spectrogram(frames)
print("Spectrogram shape:", spec.shape)
# Out:
# Frames shape: (175, 400)
# Spectrogram shape: (175, 201)

# %% [markdown]
# ## Task 2–4 Deliverable Plots
#
# Generated by `scripts/make_plots.py`, saved to `results/figures/`.
# Displayed here for quick visual reference during development.

# %%
from IPython.display import Image, display

display(Image(filename="../results/figures/time_domain_real_vs_fake.png"))
display(Image(filename="../results/figures/fft_magnitude_real_vs_fake.png"))
display(Image(filename="../results/figures/spectrogram_real_vs_fake.png"))
